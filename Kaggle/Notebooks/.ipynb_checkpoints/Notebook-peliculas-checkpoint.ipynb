# %%
import pandas as pd

# %%
df = pd.read_csv('./../Data/movies_metadata.csv')
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df.shape
# Out:
# (45466, 24)

# %%
df.info
# Out:
# <bound method DataFrame.info of        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
# ...

# %%
df.head(3)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
#
#      original_title                                           overview  ...  \
# 0         Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
# ...

# %%
df['original_title']
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 45461                        رگ خواب
# 45462            Siglo ng Pagluluwal
# 45463                       Betrayal
# 45464            Satana likuyushchiy
# 45465                       Queerama
# Name: original_title, Length: 45466, dtype: object

# %%
df.original_title
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 45461                        رگ خواب
# 45462            Siglo ng Pagluluwal
# 45463                       Betrayal
# 45464            Satana likuyushchiy
# 45465                       Queerama
# Name: original_title, Length: 45466, dtype: object

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df.loc[0]
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 10194, 'name': 'Toy Story Collection', ...
# budget                                                            30000000
# genres                   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# homepage                              http://toystory.disney.com/toy-story
# id                                                                     862
# imdb_id                                                          tt0114709
# original_language                                                       en
# original_title                                                   Toy Story
# overview                 Led by Woody, Andy's toys live happily in his ...
# popularity                                                       21.946943
# poster_path                               /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# ...

# %%
df[['original_title', 'genres']]
# Out:
#                     original_title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45461                      رگ خواب
# 45462          Siglo ng Pagluluwal
# 45463                     Betrayal
# 45464          Satana likuyushchiy
# 45465                     Queerama
#
#                                                   genres
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# ...

# %%
df.loc[[13,69], ['overview','production_companies']]
# Out:
#                                              overview  \
# 13  An all-star cast powers this epic look at Amer...
# 69  Seth Gecko and his younger brother Richard are...
#
#                                  production_companies
# 13  [{'name': 'Hollywood Pictures', 'id': 915}, {'...
# 69  [{'name': 'A Band Apart', 'id': 59}, {'name': ...

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df['original_language']=='en'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 45461    False
# 45462    False
# 45463     True
# 45464     True
# 45465     True
# Name: original_language, Length: 45466, dtype: bool

# %%
filtro = (df['adult'] == 'True') & (df['vote_average'] > 6.0)
df[filtro]
# Out:
#       adult belongs_to_collection budget  \
# 39901  True                   NaN      0
#
#                                                   genres homepage     id  \
# 39901  [{'id': 80, 'name': 'Crime'}, {'id': 27, 'name...      NaN  35731
#
#          imdb_id original_language              original_title  \
# 39901  tt1161951                en  Amateur Porn Star Killer 2
#
#                                                 overview  ... release_date  \
# 39901  Shane Ryan's sequel to the disturbing Amateur ...  ...   2008-05-13
#
#       revenue runtime                          spoken_languages    status  \
# 39901     0.0     0.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                               tagline  \
# 39901  Humiliation. Rape. Murder. You know the drill.
#
#                             title  video vote_average vote_count
# 39901  Amateur Porn Star Killer 2  False          6.3        8.0
#
# [1 rows x 24 columns]

# %%
genero = ['Drama']
filtro2 = df['genres'].isin(genero)
df.loc[filtro2, 'genres']
# Out:
# Series([], Name: genres, dtype: object)

# %%
filtro3 = df['genres'].str.contains('Horror')
df[filtro3]
# Out:
#        adult                              belongs_to_collection    budget  \
# 11     False                                                NaN         0
# 69     False  {'id': 10924, 'name': 'From Dusk Till Dawn Col...  19000000
# 75     False  {'id': 122017, 'name': 'Screamers Collection',...  20000000
# 90     False                                                NaN  47000000
# 91     False                                                NaN  14000000
# ...      ...                                                ...       ...
# 45436  False                                                NaN         0
# 45439  False                                                NaN         0
# 45456  False                                                NaN         0
# 45457  False                                                NaN         0
# 45458  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df.rename(columns={ 'vote_average':'Puntuacion', 'spoken_languages':'Idioma','original_title':'Titulo'}, inplace=True)
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'Titulo', 'overview', 'popularity',
#        'poster_path', 'production_companies', 'production_countries',
#        'release_date', 'revenue', 'runtime', 'Idioma', 'status', 'tagline',
#        'title', 'video', 'Puntuacion', 'vote_count'],
#       dtype='object')

# %%
df['genres'].replace({'id':''}, inplace= True)
df['genres']
# Out:
# 0        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                           [{'id': 35, 'name': 'Comedy'}]
#                                ...
# 45461    [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                        [{'id': 18, 'name': 'Drama'}]
# 45463    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                   []
# 45465                                                   []
# Name: genres, Length: 45466, dtype: object
